# %%
import pandas as pd
import seaborn as sns
from pylab import rcParams
import numpy as np
import matplotlib.pyplot as plt

# %%
red_wine = pd.read_csv('winequality-red.csv', delimiter=';')

# %%
def explore(dataframe):
    # Shape
    print("Total Records: ", dataframe.shape[0])
          
    #Check Missing/Null
    x = dataframe.columns[dataframe.isnull().any()].tolist()   
    if not x:
        print("No Missing/Null Records")
    else:        
        print("Found Missing Records")

# %%
explore(red_wine)
# Out:
# Total Records:  1599
# No Missing/Null Records

# %%
red_wine.shape
# Out:
# (1599, 12)

# %%
red_wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
red_wine.shift()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               7.8             0.880         0.00             2.6      0.098
# 3               7.8             0.760         0.04             2.3      0.092
# 4              11.2             0.280         0.56             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 1594            6.8             0.620         0.08             1.9      0.068
# 1595            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.550         0.10             2.2      0.062
# 1597            6.3             0.510         0.13             2.3      0.076
# 1598            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                     NaN                   NaN      NaN   NaN        NaN
# 1                    11.0                  34.0  0.99780  3.51       0.56
# 2                    25.0                  67.0  0.99680  3.20       0.68
# 3                    15.0                  54.0  0.99700  3.26       0.65
# 4                    17.0                  60.0  0.99800  3.16       0.58
# ...                   ...                   ...      ...   ...        ...
# 1594                 28.0                  38.0  0.99651  3.42       0.82
# 1595                 32.0                  44.0  0.99490  3.45       0.58
# 1596                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality
# 0         NaN      NaN
# 1         9.4      5.0
# 2         9.8      5.0
# 3         9.8      5.0
# 4         9.8      6.0
# ...       ...      ...
# 1594      9.5      6.0
# 1595     10.5      5.0
# 1596     11.2      6.0
# 1597     11.0      6.0
# 1598     10.2      5.0
#
# [1599 rows x 12 columns]

# %%
red_wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
red_wine['good'] = (red_wine['quality'] >= 6).astype(int)
red_wine.shift()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               NaN               NaN          NaN             NaN        NaN
# 1               7.4             0.700         0.00             1.9      0.076
# 2               7.8             0.880         0.00             2.6      0.098
# 3               7.8             0.760         0.04             2.3      0.092
# 4              11.2             0.280         0.56             1.9      0.075
# ...             ...               ...          ...             ...        ...
# 1594            6.8             0.620         0.08             1.9      0.068
# 1595            6.2             0.600         0.08             2.0      0.090
# 1596            5.9             0.550         0.10             2.2      0.062
# 1597            6.3             0.510         0.13             2.3      0.076
# 1598            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                     NaN                   NaN      NaN   NaN        NaN
# 1                    11.0                  34.0  0.99780  3.51       0.56
# 2                    25.0                  67.0  0.99680  3.20       0.68
# 3                    15.0                  54.0  0.99700  3.26       0.65
# 4                    17.0                  60.0  0.99800  3.16       0.58
# ...                   ...                   ...      ...   ...        ...
# 1594                 28.0                  38.0  0.99651  3.42       0.82
# 1595                 32.0                  44.0  0.99490  3.45       0.58
# 1596                 39.0                  51.0  0.99512  3.52       0.76
# 1597                 29.0                  40.0  0.99574  3.42       0.75
# 1598                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality  good
# 0         NaN      NaN   NaN
# 1         9.4      5.0   0.0
# 2         9.8      5.0   0.0
# 3         9.8      5.0   0.0
# 4         9.8      6.0   1.0
# ...       ...      ...   ...
# 1594      9.5      6.0   1.0
# 1595     10.5      5.0   0.0
# 1596     11.2      6.0   1.0
# 1597     11.0      6.0   1.0
# 1598     10.2      5.0   0.0
#
# [1599 rows x 13 columns]

# %% [markdown]
# # Найдем выбросы

# %%
rcParams['figure.figsize'] = 10, 6
sns.distplot(x=red_wine['quality'])
# Out:
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/1182301778.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_wine['quality'])
# <Axes: ylabel='Density'>

# %%
percentile_25 = np.percentile(red_wine['quality'], 25)
percentile_75 = np.percentile(red_wine['quality'], 75)

print("25 percentile:", percentile_25)
print("75 percentile:", percentile_75)
# Out:
# 25 percentile: 5.0
# 75 percentile: 6.0

# %%
delta = 1.5 * (percentile_75 - percentile_25)
delta
# Out:
# 1.5

# %% [markdown]
# Вычислим верхнюю и нижнюю границы диапазона допустимых значений

# %%
lower = percentile_25 - delta
lower
# Out:
# 3.5

# %%
upper = percentile_75 + delta
upper
# Out:
# 7.5

# %% [markdown]
# Найдем и удалим выборсы

# %%
delete_rows = red_wine[(lower >= red_wine['quality']) | (red_wine['quality'] >= upper)]
delete_rows.head()
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 267            7.9              0.35         0.46             3.6      0.078
# 278           10.3              0.32         0.45             6.4      0.073
# 390            5.6              0.85         0.05             1.4      0.045
# 440           12.6              0.31         0.72             2.2      0.072
# 455           11.3              0.62         0.67             5.2      0.086
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 267                 15.0                  37.0   0.9973  3.35       0.86
# 278                  5.0                  13.0   0.9976  3.23       0.82
# 390                 12.0                  88.0   0.9924  3.56       0.82
# 440                  6.0                  29.0   0.9987  2.88       0.82
# 455                  6.0                  19.0   0.9988  3.22       0.69
#
#      alcohol  quality  good
# 267     12.8        8     1
# 278     12.6        8     1
# 390     12.9        8     1
# 440      9.8        8     1
# 455     13.4        8     1

# %%
print("Количество найденных выбросов:", delete_rows.shape[0])
# Out:
# Количество найденных выбросов: 28

# %%
red_cleaned = red_wine.drop(delete_rows.index)
red_cleaned.shape
# Out:
# (1571, 13)

# %%
sns.distplot(x=red_cleaned['quality']);
# Out:
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/2320939298.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned['quality']);

# %% [markdown]
# Исследуем бинарные классы

# %%
plt.title("Распределение бинарных классов")
sns.countplot(x='good', data=red_cleaned)
# Out:
# <Axes: title={'center': 'Распределение бинарных классов'}, xlabel='good', ylabel='count'>

# %%
balance = red_cleaned['good'].value_counts()
balance
# Out:
# 1    837
# 0    734
# Name: good, dtype: int64

# %%
total = np.sum(balance)
zero = balance[0] / total
one = balance[1] / total
print("Доля от 0:", zero)
print("Доля от 1:", one)
# Out:
# Доля от 0: 0.4672183322724379
# Доля от 1: 0.5327816677275621

# %% [markdown]
# Медиана

# %%
red_cleaned.median()
# Out:
# fixed acidity            7.90000
# volatile acidity         0.52000
# citric acid              0.26000
# residual sugar           2.20000
# chlorides                0.07900
# free sulfur dioxide     14.00000
# total sulfur dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.10000
# quality                  6.00000
# good                     1.00000
# dtype: float64

# %% [markdown]
# Посмотрим на график с усами признака качества без выбросов

# %%
red_cleaned.boxplot(column='quality')
# Out:
# <Axes: >

# %% [markdown]
# Рассмотрим все графики распределений

# %%
for column in red_cleaned.columns:
  plt.title("Распределение значений признака: " + column)
  sns.distplot(x=red_cleaned[column])
  plt.show()
# Out:
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])
# /var/folders/1j/287nr9g51b128plm6r3b3dsh0000gn/T/ipykernel_1308/4071553567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=red_cleaned[column])

# %% [markdown]
# Рассмотрим корреляции

# %%
corr = red_cleaned.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.254979     0.668055
# volatile acidity          -0.254979          1.000000    -0.550466
# citric acid                0.668055         -0.550466     1.000000
# residual sugar             0.112726         -0.000938     0.144541
# chlorides                  0.093603          0.054441     0.210872
# free sulfur dioxide       -0.153287         -0.002193    -0.058883
# total sulfur dioxide      -0.110548          0.084952     0.039963
# density                    0.668446          0.023945     0.365142
# pH                        -0.681691          0.223166    -0.536324
# sulphates                  0.185738         -0.252713     0.311397
# alcohol                   -0.056086         -0.208159     0.111581
# quality                    0.132455         -0.371912     0.216625
# good                       0.095608         -0.313304     0.152509
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.112726   0.093603            -0.153287
# volatile acidity           -0.000938   0.054441            -0.002193
# citric acid                 0.144541   0.210872            -0.058883
# residual sugar              1.000000   0.058815             0.196394
# chlorides                   0.058815   1.000000             0.005713
# free sulfur dioxide         0.196394   0.005713             1.000000
# total sulfur dioxide        0.210238   0.050730             0.666647
# density                     0.355289   0.200790            -0.016526
# pH                         -0.087517  -0.269856             0.070912
# sulphates                   0.006907   0.382763             0.052165
# alcohol                     0.038797  -0.216637            -0.072443
# quality                     0.015644  -0.110691            -0.057308
# good                       -0.002028  -0.101997            -0.063396
#
#                       total sulfur dioxide   density        pH  sulphates  \
# fixed acidity                    -0.110548  0.668446 -0.681691   0.185738
# volatile acidity                  0.084952  0.023945  0.223166  -0.252713
# citric acid                       0.039963  0.365142 -0.536324   0.311397
# residual sugar                    0.210238  0.355289 -0.087517   0.006907
# chlorides                         0.050730  0.200790 -0.269856   0.382763
# free sulfur dioxide               0.666647 -0.016526  0.070912   0.052165
# total sulfur dioxide              1.000000  0.076190 -0.070018   0.043404
# density                           0.076190  1.000000 -0.341393   0.157177
# pH                               -0.070018 -0.341393  1.000000  -0.196786
# sulphates                         0.043404  0.157177 -0.196786   1.000000
# alcohol                          -0.209803 -0.489172  0.205099   0.086381
# quality                          -0.203880 -0.155828 -0.040834   0.241592
# good                             -0.235628 -0.151687  0.003572   0.211075
#
#                        alcohol   quality      good
# fixed acidity        -0.056086  0.132455  0.095608
# volatile acidity     -0.208159 -0.371912 -0.313304
# citric acid           0.111581  0.216625  0.152509
# residual sugar        0.038797  0.015644 -0.002028
# chlorides            -0.216637 -0.110691 -0.101997
# free sulfur dioxide  -0.072443 -0.057308 -0.063396
# total sulfur dioxide -0.209803 -0.203880 -0.235628
# density              -0.489172 -0.155828 -0.151687
# pH                    0.205099 -0.040834  0.003572
# sulphates             0.086381  0.241592  0.211075
# alcohol               1.000000  0.464963  0.428939
# quality               0.464963  1.000000  0.877288
# good                  0.428939  0.877288  1.000000

# %%
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap="BuPu")
# Out:
# <Axes: >
